# %% [raw]
# step-1 download all required libraries
# step-2 import data from source
# step-3 perform basic checks -- explore shape of data, no.of cols, no.of rows
# step-4 name of the columns
# step-5 perform 2 statistical analysis one for numerical data the other for categorical data
# step-6 null value treatment and imputation

# %%
# importing the required libraries
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# !pip install seaborn --upgrade
df=sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df.columns # gives no.of cols
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
df.shape # to know no.of rows and cols
# Out:
# (244, 7)

# %%
df.info() #gives info of the dataset including data types,memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
# float 64,float32,float16
# int64,int32,tint16,int8  
# these are available data types available in any columns of the dataset

# %%
df.describe() #gives summary of a dataset which has numerical data
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.describe(include='category') # to include different data types
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %% [raw]
# Insights
#
# 1. total_bill
# Most bills fall between $10–$20, with a few very large ones.
# Higher bills usually lead to higher tips, but not always proportionally.
#
# 2. tip
# Tips range mostly from $2–$4, skewed toward smaller amounts.
# They grow with bill size, but tip percentage varies widely.
#
# 3. sex
# Males tend to leave slightly higher tips in absolute terms.
# When normalized by bill size, gender differences are minimal.
#
# 4. smoker
# Smokers and non‑smokers tip at similar rates.
# Smokers often appear in smaller dining groups.
#
# 5. day
# Weekends (Sat/Sun) show larger bills and higher tips.
# Weekdays (Thur/Fri) have smaller bills and fewer customers.
#
# 6. time
# Lunch bills are smaller with lower tips.
# Dinner bills are larger, often with alcohol, leading to bigger tips.
#
# 7. size
# Group size ranges from 1–6, with bigger groups spending more.
# Tip percentage tends to drop slightly as group size increases.

# %% [raw]
# Null value treatment and imputation
# A. Fill the missing records:
#         1. mean median mode
#         2. domain
# B. remove the missing data:
#     1. Remove the rows in which missing position
#             dropna data loss 20
#     2. remove the columns in which missing positions
#             tip missing records

# %%
df.isna().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
(df.isna().sum())/(df.shape[0])*100
# Out:
# total_bill    0.0
# tip           0.0
# sex           0.0
# smoker        0.0
# day           0.0
# time          0.0
# size          0.0
# dtype: float64

# %%
df1=sns.load_dataset("titanic")
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df1.shape
# Out:
# (891, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df1.describe(include="object")
# Out:
#          sex embarked  who  embark_town alive
# count    891      889  891          889   891
# unique     2        3    3            3     2
# top     male        S  man  Southampton    no
# freq     577      644  537          644   549

# %%
df1.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %% [raw]
# deck percentage of missing records is more than 20 or it is 77 percent, we can remove
#
# age - np.median
# embark_town mode
# embarked median

# %%
(df1.isna().sum()/df1.shape[0])*100
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
df1.drop(columns=['deck'], inplace=True)

# %%
df1['age'] = df1['age'].fillna(df1['age'].median())

# %%
df1['embarked'] = df1['embarked'].fillna(df1['embarked'].mode()[0])

# %%
(df1.isna().sum()/df1.shape[0])*100
# Out:
# survived       0.000000
# pclass         0.000000
# sex            0.000000
# age            0.000000
# sibsp          0.000000
# parch          0.000000
# fare           0.000000
# embarked       0.000000
# class          0.000000
# who            0.000000
# adult_male     0.000000
# embark_town    0.224467
# alive          0.000000
# alone          0.000000
# dtype: float64

# %% [raw]
# univariate analysis
#
# numerical
#     1. histogram
# categorical
#     1. countplot

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          891 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     891 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  embark_town  889 non-null    object
#  12  alive        891 non-null    object
#  13  alone        891 non-null    bool
# dtypes: bool(2), category(1), float64(2), int64(4), object(5)
# memory usage: 79.4+ KB

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['survived'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['pclass'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['sibsp'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['parch'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['age'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['fare'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['adult_male'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['deck'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['embark_town'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['alive'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['alone'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['alone'])
plt.show()

# %% [markdown]
# # bivariate analysis

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['age'],hue=df1['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['pclass'],hue=df1['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['sibsp'],hue=df1['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['parch'],hue=df1['sex'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['age'],hue=df1['embarked'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['age'],hue=df1['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['survived'],hue=df1['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['sibsp'],hue=df1['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['parch'],hue=df1['class'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['survived'],hue=df1['who'],kde=True)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['sex'],hue=df1['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['sex'],hue=df1['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['alone'],hue=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['class'],hue=df1['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.histplot(x=df1['alone'],hue=df1['sex'])
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'],y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['pclass'],y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'],y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'],y=df1['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'],y=df1['sibsp'])
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'],y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['pclass'],y=df1['survived'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['pclass'],y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['pclass'],y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['pclass'],y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['fare'],y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['fare'],y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x=df1['sex'], hue=df1['survived'])
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['age'], y=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['age'])
plt.show()

# %% [raw]
# bivariate
# barplot
# one should be either numerical or categorical
# x=nunerical or y=categorical and vice versa

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['age'], y=df1['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['deck'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['deck'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['deck'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['deck'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['deck'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['pclass'])
plt.show()

# %%
in this way is done

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['class'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['class'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['class'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['class'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['class'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alone'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alone'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alone'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alone'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alone'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['who'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['embarked'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alive'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alive'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alive'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alive'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['alive'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['adult_male'], y=df1['age'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['adult_male'], y=df1['sibsp'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['adult_male'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['adult_male'], y=df1['fare'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['adult_male'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['parch'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['fare'])
plt.show()

# %%
sns.boxplot(x=df1['age'])
plt.show()

# %%
sns.boxplot(x=df1['sibsp'])
plt.show()

# %%
sns.boxplot(x=df1['parch'])
plt.show()

# %%
sns.boxplot(x=df1['fare'])
plt.show()

# %%
sns.boxplot(x=df1['pclass'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['sex'], y=df1['age'], palette='pastel')
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_15808\3904445523.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x=df1['sex'], y=df1['age'], palette='pastel')

# %%
sns.boxplot(x=df1['sex'], y=df1['sibsp'])
plt.show()

# %%
sns.boxplot(x=df1['sex'], y=df1['parch'])
plt.show()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['sex'], y=df1['fare'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['sex'], y=df1['pclass'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['class'], y=df1['age'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['class'], y=df1['sibsp'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['class'], y=df1['parch'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['class'], y=df1['fare'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['class'], y=df1['pclass'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['who'], y=df1['age'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['who'], y=df1['sibsp'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['who'], y=df1['parch'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x=df1['who'], y=df1['fare'], palette='pastel')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.swarmplot(x=df1['sex'], y=df1['class'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['who'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['alone'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['alive'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['deck'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.stripplot(x=df1['sex'], y=df1['adult_male'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['sibsp'],hue=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['parch'],hue=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['fare'],hue=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['pclass'],hue=df1['sex'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['sibsp'], y=df1['age'],hue=df1['sex'])
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['parch'],hue=df1['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.scatterplot(x=df1['age'], y=df1['sibsp'],hue=df1['embarked'])
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.barplot(x=df1['sex'], y=df1['age'],hue=df1['embarked'])
plt.show()
