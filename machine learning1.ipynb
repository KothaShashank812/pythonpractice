# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
ad = pd.read_csv("C:/Users/Admin/Downloads/Advertising.csv")

# Display first few rows
print(ad.head())

# Display dataset information
print(ad.info())
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB
# None

# %%
ad.shape
# Out:
# (200, 5)

# %%
ad.isna()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
sns.histplot(x=ad['TV'],kde='true',bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=ad['Radio'],kde='true',bins=40)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
#Normal distribution because we considering -0.5 to 0.5,it is negative or left skewed
ad['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
ad['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %%
#Normal distribution because we considering -0.5 to 0.5
ad['Radio'].skew()
# Out:
# np.float64(0.09417463149664404)

# %%
ad['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
ad['Unnamed: 0'].skew()
# Out:
# np.float64(0.0)

# %%
sns.scatterplot(x=ad['Radio'], y=ad['Sales'])
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x=ad['TV'], y=ad['Sales'])
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x=ad['Newspaper'], y=ad['Sales'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.scatterplot(x=ad['Unnamed: 0'], y=ad['Sales'])
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Sales'>

# %%
df.rename(columns={'Unnamed: 0': 'Serial'}, inplace=True)

# %%
df.columns
# Out:
# Index(['Serial', 'TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.corr()
# Out:
#              Serial        TV     Radio  Newspaper     Sales
# Serial     1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV         0.017715  1.000000  0.054809   0.056648  0.782224
# Radio     -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales     -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.drop('Unnamed: 0',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
df.drop('Serial',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
# ----> 2 r2score=r2_score(y_test,y_predict)
#       3 r2score
#
# NameError: name 'y_test' is not defined

# %%
X=df[['TV']] ## X variable contains one feature
y=df.Sales ## y is Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

from sklearn.metrics import (r2_score, mean_squared_error, mean_absolute_error,
root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE : ",mean_squared_error(y_test,y_predict))
print("MAE : ",mean_absolute_error(y_test,y_predict))
print("RMSE : ",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE :  13.06226628830567
# MAE :  2.990565035759226
# RMSE :  3.6141757412037494

# %%
X=df[['Radio']] ## X variable contains one feature
y=df.Sales ## y is Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

from sklearn.metrics import (r2_score, mean_squared_error, mean_absolute_error,
root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(y_test, y_predict)
r2 * 100
# Out:
# 37.86450118378573

# %%
X=df[['Newspaper']] ## X variable contains one feature
y=df.Sales ## y is Target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=4)

# %%
print(len(X_test))
print(len(X_train))
# Out:
# 40
# 160

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

from sklearn.metrics import (r2_score, mean_squared_error, mean_absolute_error,
root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004928

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(y_test, y_predict)
r2 * 100
# Out:
# -11.72879616100493

# %%
X=df[['TV','Newspaper','Radio']] ## X variable contains all feature
y=df.Sales ## y is Target

# %%
X
# Out:
#         TV  Newspaper  Radio
# 0    230.1       69.2   37.8
# 1     44.5       45.1   39.3
# 2     17.2       69.3   45.9
# 3    151.5       58.5   41.3
# 4    180.8       58.4   10.8
# ..     ...        ...    ...
# 195   38.2       13.8    3.7
# 196   94.2        8.1    4.9
# 197  177.0        6.4    9.3
# 198  283.6       66.2   42.0
# 199  232.1        8.7    8.6
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train,y_test=train_test_split(X,y, test_size=0.2, random_state=4)

# %%
# Step 3 Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() # object creation
LR.fit(X_train,y_train) # training of linear regression
y_predict=LR.predict(X_test)

from sklearn.metrics import (r2_score, mean_squared_error, mean_absolute_error,
root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9085774752313167

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

r2 = r2_score(y_test, y_predict)
r2 * 100
# Out:
# 90.85774752313168
